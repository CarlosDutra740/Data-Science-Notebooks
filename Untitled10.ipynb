# %%
# !pip install ssml-builder
from ssml_builder.core import Speech
# Out:
# Collecting ssml-builder
#   Downloading ssml_builder-1.1.1.tar.gz (3.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ssml-builder
#   Building wheel for ssml-builder (setup.py) ... done
#   Created wheel for ssml-builder: filename=ssml_builder-1.1.1-py3-none-any.whl size=3619 sha256=8533a6f8cfdf4ab62daf43d8c983edff66d10758b9882c8a4fda3c27d78cb7b5
#   Stored in directory: /root/.cache/pip/wheels/0e/ac/f5/790afdb24570502cf59d943c7950fe7a8be95cc16507c8c970
# Successfully built ssml-builder
# Installing collected packages: ssml-builder
# Successfully installed ssml-builder-1.1.1

# %%
speech = Speech()
speech.add_text('sample text')
speech.speak()
# Out:
# '<speak>sample text</speak>'

# %%
speech = Speech()
speech.lang(value="Paris", lang="fr-FR")
speech.speak()
# Out:
# '<speak><lang xml:lang="fr-FR">Paris</lang></speak>'

# %%
# !pip install gtts
from gtts import gTTS
import IPython
# Out:
# Collecting gtts
#   Downloading gTTS-2.5.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gtts) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gtts) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2023.11.17)
# Installing collected packages: gtts
# Successfully installed gtts-2.5.0

# %%
# prompt: reproduza o audio com tts

from gtts import gTTS
speech = gTTS(speech)
speech = str(speech)
speech.save('hello.mp3')
IPython.display.Audio('hello.mp3')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-0d4bd3b34d46> in <cell line: 6>()
#       4 speech = gTTS(speech)
#       5 speech = str(speech)
# ----> 6 speech.save('hello.mp3')
#       7 IPython.display.Audio('hello.mp3')
#
# AttributeError: 'str' object has no attribute 'save'
