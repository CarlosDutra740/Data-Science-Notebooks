# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

#Carregar arquivo de áudio
def load_audio(file_path):
  signal, sr = librosa.load(file_path,sr=None)
  return signal, sr

#Plot sinal de audio
def plot_waveform(signal,sr):
  plt.figure(figsize=(10,4))
  librosa.display.waveshow(signal, sr=sr)
  plt.title("Sinal de Audio")
  plt.xlabel("Tempo (s)")
  plt.ylabel("Amplitude")
  plt.show()

def compute_fft(signal):
  fft_result = np.fft.fft(signal)
  return fft_result

def plot_fft(fft_result, sr, label = None):
  freqs = np.fft.fftfreq(len(fft_result), 1/sr)
  magnitude = np.abs(fft_result)
  plt.figure(figsize=(10,4))
  plt.plot(freqs, magnitude)
  plt.title("Transformada Rápida de Fourier (FFT)")
  plt.xlabel("Frequência (Hz)")
  plt.ylabel("Magnitude")
  plt.xlim(0,500)
  plt.show()

def plot_spectrogram(signal, sr):
  D = librosa.amplitude_to_db(np.abs(librosa.stft(signal)), ref=np.max)
  plt.figure(figsize=(10,4))
  librosa.display.specshow(D, y_axis='linear', sr=sr, x_axis='time')
  plt.colorbar(format='%+2.0f dB')
  plt.title("Espectograma")
  plt.xlabel("Tempo (s)")
  plt.ylabel("Frequência (Hz)")
  plt.ylim(0,2000)
  plt.xlim(0,2)
  plt.show()

# %%
#Diretório do áudio
file_path = "a.wav"

#Carregar o áudio
signal,sr = load_audio(file_path)

#Plot o sinal de áudio
plot_waveform(signal,sr)

# %%
#Calcular e plotar a FFT do sinal de som
fft_result = compute_fft(signal)
plot_fft(fft_result,sr)

# %%
#Calcular e plotar o espectograma
plot_spectrogram(signal,sr)

# %%
#Diretório do áudio
file_path = "e.wav"

#Carregar o áudio
signal,sr = load_audio(file_path)

#Plot o sinal de áudio
plot_waveform(signal,sr)
#Calcular e plotar a FFT do sinal de som
fft_result = compute_fft(signal)
plot_fft(fft_result,sr)

# %%
#Diretório do áudio
file_path = "i.wav"

#Carregar o áudio
signal,sr = load_audio(file_path)

#Plot o sinal de áudio
plot_waveform(signal,sr)
#Calcular e plotar a FFT do sinal de som
fft_result = compute_fft(signal)
plot_fft(fft_result,sr)

# %%
#Diretório do áudio
file_path = "o.wav"

#Carregar o áudio
signal,sr = load_audio(file_path)

#Plot o sinal de áudio
plot_waveform(signal,sr)
#Calcular e plotar a FFT do sinal de som
fft_result = compute_fft(signal)
plot_fft(fft_result,sr)

# %%
#Diretório do áudio
file_path = "u.wav"

#Carregar o áudio
signal,sr = load_audio(file_path)

#Plot o sinal de áudio
plot_waveform(signal,sr)
#Calcular e plotar a FFT do sinal de som
fft_result = compute_fft(signal)
plot_fft(fft_result,sr)

# %%
#Diretório do áudio
file_path = "ba.wav"

#Carregar o áudio
signal,sr = load_audio(file_path)

#Plot o sinal de áudio
plot_waveform(signal,sr)
#Calcular e plotar a FFT do sinal de som
fft_result = compute_fft(signal)
plot_fft(fft_result,sr)

# %%
#Diretório do áudio
file_path = "be.wav"

#Carregar o áudio
signal,sr = load_audio(file_path)

#Plot o sinal de áudio
plot_waveform(signal,sr)
#Calcular e plotar a FFT do sinal de som
fft_result = compute_fft(signal)
plot_fft(fft_result,sr)

# %%
#Diretório do áudio
file_path = "ca.wav"

#Carregar o áudio
signal,sr = load_audio(file_path)

#Plot o sinal de áudio
plot_waveform(signal,sr)
#Calcular e plotar a FFT do sinal de som
fft_result = compute_fft(signal)
plot_fft(fft_result,sr)

# %%
#Diretório do áudio
file_path = "da.wav"

#Carregar o áudio
signal,sr = load_audio(file_path)

#Plot o sinal de áudio
plot_waveform(signal,sr)
#Calcular e plotar a FFT do sinal de som
fft_result = compute_fft(signal)
plot_fft(fft_result,sr)

# %%
#Diretório do áudio
file_path = "do.wav"

#Carregar o áudio
signal,sr = load_audio(file_path)

#Plot o sinal de áudio
plot_waveform(signal,sr)
#Calcular e plotar a FFT do sinal de som
fft_result = compute_fft(signal)
plot_fft(fft_result,sr)

# %% [markdown]
# Vamos comparar a palavra banana com o fonema -ba-

# %%
file_path_1 = "ba.wav"
file_path_2 = "banana.wav"

# Carregar os áudios
signal_1, sr_1 = load_audio(file_path_1)
signal_2, sr_2 = load_audio(file_path_2)

# Calcular a FFT para cada áudio
fft_result_1 = np.fft.fft(signal_1)
fft_result_2 = np.fft.fft(signal_2)


plot_fft(fft_result_1, sr_1, label='Audio 1')
plot_fft(fft_result_2, sr_2, label='Audio 2')

# %%
file_path_1 = "a.wav"
file_path_2 = "banana.wav"

# Carregar os áudios
signal_1, sr_1 = load_audio(file_path_1)
signal_2, sr_2 = load_audio(file_path_2)

# Calcular a FFT para cada áudio
fft_result_1 = np.fft.fft(signal_1)
fft_result_2 = np.fft.fft(signal_2)


plot_fft(fft_result_1, sr_1, label='Audio 1')
plot_fft(fft_result_2, sr_2, label='Audio 2')

plot_spectrogram(signal_1, sr_1)
plot_spectrogram(signal_2, sr_2)

# %%
file_path_1 = "e.wav"
file_path_2 = "bode.wav"

# Carregar os áudios
signal_1, sr_1 = load_audio(file_path_1)
signal_2, sr_2 = load_audio(file_path_2)

# Calcular a FFT para cada áudio
fft_result_1 = np.fft.fft(signal_1)
fft_result_2 = np.fft.fft(signal_2)


plot_fft(fft_result_1, sr_1, label='Audio 1')
plot_fft(fft_result_2, sr_2, label='Audio 2')

plot_spectrogram(signal_1, sr_1)
plot_spectrogram(signal_2, sr_2)

# %%
file_path_1 = "ca.wav"
file_path_2 = "casa.wav"

# Carregar os áudios
signal_1, sr_1 = load_audio(file_path_1)
signal_2, sr_2 = load_audio(file_path_2)

# Calcular a FFT para cada áudio
fft_result_1 = np.fft.fft(signal_1)
fft_result_2 = np.fft.fft(signal_2)


plot_fft(fft_result_1, sr_1, label='Audio 1')
plot_fft(fft_result_2, sr_2, label='Audio 2')

plot_spectrogram(signal_1, sr_1)
plot_spectrogram(signal_2, sr_2)

# %%
file_path_1 = "a.wav"
file_path_2 = "bola.wav"

# Carregar os áudios
signal_1, sr_1 = load_audio(file_path_1)
signal_2, sr_2 = load_audio(file_path_2)

# Calcular a FFT para cada áudio
fft_result_1 = np.fft.fft(signal_1)
fft_result_2 = np.fft.fft(signal_2)


plot_fft(fft_result_1, sr_1, label='Audio 1')
plot_fft(fft_result_2, sr_2, label='Audio 2')

plot_spectrogram(signal_1, sr_1)
plot_spectrogram(signal_2, sr_2)

# %%
file_path_1 = "ca.wav"
file_path_2 = "café.wav"

# Carregar os áudios
signal_1, sr_1 = load_audio(file_path_1)
signal_2, sr_2 = load_audio(file_path_2)

# Calcular a FFT para cada áudio
fft_result_1 = np.fft.fft(signal_1)
fft_result_2 = np.fft.fft(signal_2)


plot_fft(fft_result_1, sr_1, label='Audio 1')
plot_fft(fft_result_2, sr_2, label='Audio 2')

plot_spectrogram(signal_1, sr_1)
plot_spectrogram(signal_2, sr_2)

# %%
file_path_1 = "da.wav"
file_path_2 = "do.wav"
file_path_3 = "dado.wav"

# Carregar os áudios
signal_1, sr_1 = load_audio(file_path_1)
signal_2, sr_2 = load_audio(file_path_2)
signal_3, sr_3 = load_audio(file_path_3)

# Calcular a FFT para cada áudio
fft_result_1 = np.fft.fft(signal_1)
fft_result_2 = np.fft.fft(signal_2)

fft_result_3 = np.fft.fft(signal_3)


plot_fft(fft_result_1, sr_1, label='Audio 1')
plot_fft(fft_result_2, sr_2, label='Audio 2')
plot_fft(fft_result_2, sr_2, label='Audio 3')

plot_spectrogram(signal_1, sr_1)
plot_spectrogram(signal_2, sr_2)
plot_spectrogram(signal_3, sr_3)

# %% [markdown]
# Neste último caso, foi possível verificar que a palavra dado é a soma dos fonemas de da e do, o resto, por falta de janelamento, ficou dúbio.
