# %%
# Instalar a biblioteca gTTS
# !pip install gtts

# %%
# Importar as bibliotecas necessárias
from gtts import gTTS
import IPython.display as ipd

# Função para converter texto em fala
def gerar_voz_google(texto, idioma='pt'):
    output_file = "output.mp3"
    tts = gTTS(text=texto, lang=idioma)
    tts.save(output_file)
    return output_file

# Entrada do usuário
frase = input("Digite uma frase para converter em voz: ")

# Gerar e reproduzir o áudio
arquivo_audio = gerar_voz_google(frase)
ipd.display(ipd.Audio(arquivo_audio))
# Out:
# Digite uma frase para converter em voz: bem vindo ao vale sul shopping
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
